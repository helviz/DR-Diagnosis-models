# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
# Dataset path and categories
train_dir = "/kaggle/input/undersample-majority/undersample_split/1.train"
val_dir = "/kaggle/input/undersample-majority/undersample_split/2.val"

categories = [
    "1._No_DR_signs",
    "2.Mild(or_early)_NPDR",
    "3._Moderate_NPDR",
    "4._Severe_NPDR",
    "5._Very_Severe_NPDR",
    "6._PDR",
    "7._Advanced_PDR"
]

# %%
# Parameters
batch_size = 32
img_size = (224, 224)
epochs = 20
initial_learning_rate = 0.001

# Data generators for training and validation
datagen = ImageDataGenerator(rescale=1.0 / 255.0)

train_gen = datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_gen = datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 467 images belonging to 7 classes.
# Found 100 images belonging to 7 classes.

# %%
# Model definition
base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
output = Dense(len(categories), activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch % 5 == 0 and epoch > 0:
        return lr * 0.5
    return lr

lr_callback = LearningRateScheduler(scheduler)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Train the model
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    callbacks=[lr_callback]
)

# Evaluate model and calculate metrics
val_gen.reset()
y_true = val_gen.classes
y_pred = np.argmax(model.predict(val_gen), axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=categories))

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12, 8))
plt.imshow(conf_matrix, cmap='Blues')
plt.colorbar()
plt.xticks(np.arange(len(categories)), categories, rotation=45)
plt.yticks(np.arange(len(categories)), categories)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Learning rate and training rate tracking
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 111s 5s/step - accuracy: 0.2847 - loss: 2.1096 - val_accuracy: 0.4900 - val_loss: 1.3806 - learning_rate: 0.0010
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - accuracy: 0.5811 - loss: 1.1688 - val_accuracy: 0.6100 - val_loss: 1.0877 - learning_rate: 0.0010
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.7082 - loss: 0.8523 - val_accuracy: 0.6900 - val_loss: 0.9378 - learning_rate: 0.0010
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - accuracy: 0.7594 - loss: 0.7703 - val_accuracy: 0.7000 - val_loss: 0.8689 - learning_rate: 0.0010
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.7967 - loss: 0.6305 - val_accuracy: 0.7800 - val_loss: 0.7852 - learning_rate: 0.0010
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - accuracy: 0.8309 - loss: 0.5453 - val_accuracy: 0.6700 - val_loss: 0.8132 - learning_rate: 5.0000e-04
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 83s 5s/step - accuracy: 0.8405 - loss: 0.5646 - val_accuracy: 0.6800 - val_loss: 0.7687 - learning_rate: 5.0000e-04
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.8560 - loss: 0.4598 - val_accuracy: 0.7000 - val_loss: 0.8471 - learning_rate: 5.0000e-04
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 87s 5s/step - accuracy: 0.8720 - loss: 0.4286 - val_accuracy: 0.7100 - val_loss: 0.7729 - learning_rate: 5.0000e-04
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.8448 - loss: 0.4795 - val_accuracy: 0.7400 - val_loss: 0.7160 - learning_rate: 5.0000e-04
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 88s 5s/step - accuracy: 0.9190 - loss: 0.3559 - val_accuracy: 0.7500 - val_loss: 0.7042 - learning_rate: 2.5000e-04
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.8739 - loss: 0.4160 - val_accuracy: 0.7400 - val_loss: 0.7438 - learning_rate: 2.5000e-04
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - accuracy: 0.8953 - loss: 0.3757 - val_accuracy: 0.7500 - val_loss: 0.6975 - learning_rate: 2.5000e-04
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 86s 5s/step - accuracy: 0.9080 - loss: 0.3328 - val_accuracy: 0.7400 - val_loss: 0.6956 - learning_rate: 2.5000e-04
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.9068 - loss: 0.3754 - val_accuracy: 0.7600 - val_loss: 0.6987 - learning_rate: 2.5000e-04
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.9087 - loss: 0.3371 - val_accuracy: 0.7500 - val_loss: 0.6884 - learning_rate: 1.2500e-04
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 80s 5s/step - accuracy: 0.9221 - loss: 0.3161 - val_accuracy: 0.7500 - val_loss: 0.6873 - learning_rate: 1.2500e-04
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.9112 - loss: 0.3150 - val_accuracy: 0.7500 - val_loss: 0.6863 - learning_rate: 1.2500e-04
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.9181 - loss: 0.3262 - val_accuracy: 0.7500 - val_loss: 0.6818 - learning_rate: 1.2500e-04
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 79s 5s/step - accuracy: 0.9017 - loss: 0.3465 - val_accuracy: 0.7500 - val_loss: 0.6818 - learning_rate: 1.2500e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 25s 5s/step
#
# Classification Report:
#                        precision    recall  f1-score   support
#
#        1._No_DR_signs       0.14      0.13      0.14        15
# 2.Mild(or_early)_NPDR       0.27      0.27      0.27        15
#      3._Moderate_NPDR       0.00      0.00      0.00        12
#        4._Severe_NPDR       0.27      0.27      0.27        15
#   5._Very_Severe_NPDR       0.12      0.13      0.12        15
#                6._PDR       0.10      0.15      0.12        13
#       7._Advanced_PDR       0.00      0.00      0.00        15
#
#              accuracy                           0.14       100
#             macro avg       0.13      0.14      0.13       100
#          weighted avg       0.13      0.14      0.13       100
